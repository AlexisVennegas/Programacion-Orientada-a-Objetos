# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # CAPITULO 1
# ¿En qué año comenzaron las bases de datos?
#
# - que es hace el dba
# - años 50 relacionales
# - años 80 standar sql
# - 2000 relacionales con no relacionales facebook
# - 2010 cloud dba
# - 2015-2020 IA
#
#
# QUE ES UNA BBASE D DATOS UN AAPLICACION CON REGLAS ALMACENA INFORMACION EB BASE A UNAS REGLAS TABLA CON CAMPO, LO MAS IMPORANTE TES EL DATO
#
#  TABLA DE DATOS RELACIONAL
# 1.- FIABILIDAD -
# 2.- SEGURIDAD
# 3.- ESTRUCTURADA
# 4.- ESCALABILIDAD
# 5.-

# %% [markdown]
# # CAPITULO 3
#
#
#
# -DOMINIO ESTUDIAR
# - VISTAS  CONSULTA ALMACENADA
# - REEGLAS DE CODD 12 + 1
# - estudiar TODAS lAS REGLAS de codd
# - estudiar las restricciones de las fk, son 5, no hacer la cascade, tambien esta set default, set null, no action ,
# - Normalizacion:
#      - 1 regla todas las tablas  tengan pega1 que tengan pk
#      - 2 regla que todos los campos tengan relacion con el nombre de la pk, example alumno y todos sus alumnos si tienen relacion y se puede dejar en la tabla
#      - 3   regla: las tablas que tengamos tienen relacion con la con sus campos, (equipo y aforo) en este caso si tienene relacion pero son sus fk
#      - 4.- se repiten los campos
#      - 5.- pasar las fk de una tabla distina en vez de tenerla toda en una ejem empleados

# %% [markdown]
# # funciones de registro unidad 2176
#
# se llaman as porque van registor a registro ejecutandose
#
# - Estudiar las funciones de registro, avg, nvl, count,  max, min (nvl mas importante)
# - ![image.png](attachment:image.png)
# - la foto es la conversion de datos que tienen oracle y sql
# - subqueries - agrupacion
# - procedimientos y funciones
# - saber lo que es un ide
# - que es mysqlserver motores que tiene, indodb examendb
# - funciones workbench
# - sintaxis
# - transacciones
# ![image-2.png](attachment:image-2.png)
