# %% [markdown]
# # Sistemas Operativos

# %% [markdown]
# El sistema operativo es el software básico que controla una computadora. A grandes rasgos
# tiene tres grandes funciones: coordinar y manipular el hardware del sistema informático
# (memoria, impresoras, unidades de almacenamiento, periféricos, etc.)

# %% [markdown]
# ![DALL·E 2024-10-31 10.12.51 - A detailed schematic diagram illustrating the components of an operating system. Show the following layers in a stacked format, from bottom to top_ 1.webp](<attachment:DALL·E 2024-10-31 10.12.51 - A detailed schematic diagram illustrating the components of an operating system. Show the following layers in a stacked format, from bottom to top_ 1.webp>)

# %% [markdown]
# # Multiusuario

# %% [markdown]
# Un sistema operativo multiusuario es un sistema que puede dar servicio a varios usuarios de
# forma simultánea. Hay que tener en cuenta que un sistema con varias cuentas de usuario no
# es necesariamente un sistema multiusuario. Por ejemplo, las versiones domésticas de los
# sistemas Windows® permiten tener varias cuentas de usuario en el mismo sistema operativo
# pero no permiten que haya varios usuarios trabajando en el sistema al mismo tiempo. Las
# versiones Server de Windows® sí permiten esta característica a través de terminal server.
# Por el contrario, las versiones Linux sí son multiusuario desde hace mucho tiempo.

# %% [markdown]
# - Centralizados. En este modelo un ordenador central se encarga de todo el
# procesamiento y los usuarios se conectan a él a través de terminales que carecen de
# memoria y procesador.
# - Distribuidos. Permiten distribuir los trabajos, tareas o procesos entre un conjunto de
# procesadores, que pueden estar en el mismo equipo o en equipos distintos.
# - De escritorio. Es el utilizado habitualmente por los equipos de sobremesa, estaciones
# de trabajo y portátiles
# - ● En red. Son los que permiten mantener unidad entre dos o más ordenadores a través
# de algún medio de comunicación para poder compartir los recursos y la información
# del sistema.

# %% [markdown]
# # Principales Funciones de los sistemas operativos

# %% [markdown]
# - Políticas de reparto de tiempo de proceso. Controla la ejecución de varios procesos a
# la vez, repartiendo los recursos del ordenador (procesador, memoria, espacio de
# almacenamiento…) a los distintos programas que se están ejecutando.
# - Control y manejo de los dispositivos de E/S. Controla y organiza los dispositivos
# conectados al sistema.
# - Control de recursos. Coordinar y manipular el hardware del sistema informático. Se
# encarga del funcionamiento coordinado de todos los componentes para que funcionen
# como una sola máquina.
# - Administra y mantiene los sistemas de archivo de disco permitiendo guardar la
# información en las unidades de almacenamiento en forma de ficheros y directorios.
# - Gestiona y mantiene usuarios y grupos de usuarios pudiendo establecer privilegios y
# restricciones a las diferentes cuentas individuales o grupales.
# - Ofrece una base estándar sobre la que ejecutar otros programas permitiendo diseñar
# software de aplicación sin necesidad de tener en cuenta el hardware particular de
# cada sistema.
# - Permite la interacción entre el sistema y los usuarios permitiendo su manejo de forma
# fácil e intuitiva a través de la interfaz gráfica o GUI.
# - Detecta e informa de los errores que se produzcan.

# %% [markdown]
# # Paginado

# %% [markdown]
# traslado de informacion de la memoria virtual a la memoria y viceversa

# %% [markdown]
# # Políticas de reparto de tiempo de Proceso

# %% [markdown]
# ### Algunos algoritmos de planificación

# %% [markdown]
# - FIFO o FCFS (First Come First Served): Atiende a cada proceso completamente en su turno, uno después del otro, hasta terminar.
# - Round Robin: Da a cada proceso un poquito de tiempo, luego pasa al siguiente y vuelve a dar otra oportunidad más adelante, y así en ciclos.
# - SJF: Atiende primero las tareas más cortas, para reducir la espera de las tareas rápidas.
# - Planificación con múltiples colas: ivide las tareas en varias filas según su tipo o prioridad, y organiza la atención según la importancia de cada fila.
# - Planificación por prioridades: Atiende primero las tareas más importantes o urgentes, sin importar el tiempo de espera o de ejecución.

# %% [markdown]
# # Manejo de Interrupciones y dispositivos

# %% [markdown]
# El sistema de entrada/salida es aquella parte del sistema operativo encargada de abstraerse
# los dispositivos de entrada/salida conectados al equipo y ofrecer una visión más simplificada
# de los mismos de tal forma que los demás componentes del SSOO o software puedan hacer
# uso de ellos de una manera fácil.
#  Los dispositivos de entrada/salida se pueden clasificar en tres grupos:
# - Dispositivos de almacenamiento. Como su nombre indica, van a servir al sistema
# para almacenar la información del mismo de forma no volátil. Son dispositivos de este
# tipo las unidades SSD, los discos, los pendrives, las tarjetas de memoria, etc.
# - Dispositivos de comunicaciones. Permiten conectar el sistema con otros equipos a
# través de una red. La tarjeta de red es un dispositivo de este tipo.
# - Dispositivos de interfaz de usuario. Permiten la interacción entre el usuario y el
# equipo. Ratones, teclado,pantalla, impresoras, etc., son dispositivos de este tipo.

# %% [markdown]
# # Bloqueo de Recursos

# %% [markdown]
# - Se llaman recursos apropiativos a aquellos que pueden ser retirados sin causar
# ningún daño.
# - Se llaman recursos no apropiativos a aquellos que al ser retirados el proceso
# propietario falla.

# %% [markdown]
# # Capítulo II Sistemas de archivo

# %% [markdown]
# ## Implementación de sistemas de archivo

# %% [markdown]
#  se refiere al diseño y construcción del software que permite a un sistema operativo organizar, almacenar, recuperar y gestionar los datos en dispositivos de almacenamiento, como discos duros, SSDs o unidades flash.

# %% [markdown]
# ## Capas de abstracción

# %% [markdown]
# En un sistema de archivos, las **capas de abstracción** organizan el flujo de datos desde las aplicaciones hasta el hardware de almacenamiento. Esto permite manejar archivos de manera eficiente y mantener la integridad y seguridad de los datos. Estas capas típicas son:
#
# ### 1. **Capa de Aplicación**
#    - Es la capa más alta, donde interactúan los programas o aplicaciones del usuario con el sistema de archivos, a través de operaciones como abrir, leer, escribir, o cerrar archivos.
#    - A través de esta capa, las aplicaciones hacen solicitudes de E/S (entrada/salida) al sistema de archivos, sin preocuparse por los detalles de almacenamiento físico.
#
# ### 2. **Capa del Sistema de Archivos Lógico**
#    - Esta capa organiza y gestiona la estructura lógica de los datos y metadatos de los archivos, como nombres de archivos, permisos, estructura de directorios y ubicaciones.
#    - Incluye la gestión de permisos de acceso, los sistemas de control de usuarios, y los aspectos lógicos de la organización de archivos y carpetas.
#    - Aquí, el sistema de archivos traduce las operaciones de archivos de alto nivel a bloques de datos, manejando aspectos como la fragmentación.
#
# ### 3. **Capa de Gestión de Archivos**
#    - En esta capa se maneja la asignación de bloques a los archivos, y se realiza el seguimiento de los bloques libres y ocupados en el disco.
#    - Es responsable de administrar los espacios libres y asignar almacenamiento a los archivos según las solicitudes de la capa superior.
#    - Esta capa puede incluir métodos como el uso de tablas (por ejemplo, FAT), índices (como en NTFS), o estructuras de árboles (como en ext4) para localizar archivos.
#
# ### 4. **Capa de Sistema de Entrada/Salida (E/S) de Archivos**
#    - Esta capa traduce las operaciones de archivos a operaciones de bloques de datos en el almacenamiento físico.
#    - A través de esta capa, el sistema de archivos interactúa con los controladores de dispositivos para escribir y leer datos en bloques específicos.
#    - También incluye el manejo de búferes y cachés para optimizar el rendimiento de lectura/escritura y reducir el tiempo de espera de acceso a los datos.
#
# ### 5. **Capa del Controlador de Dispositivos**
#    - Esta capa actúa como intermediario entre el sistema operativo y el hardware de almacenamiento.
#    - Aquí se encuentran los controladores de hardware específicos que traducen las operaciones genéricas de E/S en comandos específicos del dispositivo.
#    - Los controladores también gestionan detalles como la sincronización de operaciones y el manejo de interrupciones de hardware.
#
# ### 6. **Capa Física (Hardware)**
#    - Es la capa más baja, donde se almacenan físicamente los datos en los discos duros, SSDs, o cualquier dispositivo de almacenamiento.
#    - Esta capa define cómo se estructuran los datos a nivel físico, manejando la posición en el disco o memoria y controlando el acceso eléctrico o magnético a los datos.
#
# ### Resumen de las Capas
#
# | Capa                    | Función Principal                                                  |
# |-------------------------|--------------------------------------------------------------------|
# | **Aplicación**          | Interacción de programas con archivos (abrir, cerrar, leer, etc.) |
# | **Sistema de Archivos Lógico** | Organización lógica de archivos y directorios                |
# | **Gestión de Archivos** | Asignación y gestión de bloques de datos                           |
# | **Sistema de E/S de Archivos** | Traducción a operaciones de bloques en disco               |
# | **Controlador de Dispositivos** | Comunicación directa con el hardware                      |
# | **Física (Hardware)**   | Almacenamiento físico de datos                                    |
#
# Estas capas de abstracción permiten que el sistema de archivos maneje de forma flexible y eficiente la gestión de datos en los dispositivos, sin que las aplicaciones necesiten conocer la complejidad del almacenamiento físico.

# %% [markdown]
# ## Comparación de sistemas de archivos

# %% [markdown]
# - NTFS: Sistema de Windows con funciones avanzadas (compresión, cifrado) pero ocupa mucho espacio.
# - HFS+: Usado por Apple, permite cifrado pero no compresión.
# - EXT4: Común en Linux, es rápido y eficiente, sin compresión ni cifrado, pero compatible con EXT3.

# %% [markdown]
# # Jounal

# %% [markdown]
# El journal en un sistema de ficheros consiste básicamente en una lista de
# transacciones, de esta manera las recuperaciones ante posibles accidentes son mucho más
# ágiles que en sistemas sin journaling.
# Existen muchos sistemas de ficheros con journaling como por ejemplo EXT4, NTFS,
# ReiserFS, JFS, etc.

# %% [markdown]
# ## Capítulo III Multiproceso, Multitarea y MultiUsuario

# %% [markdown]
# ## Multiproceso
# Un sistema operativo multiproceso es aquel que puede ejecutar varios procesos de forma concurrente (a la vez). Para que se puedan ejecutar varios procesos a la vez, es necesario tener un sistema multiprocesador (con varios procesadores).
#
# El objetivo de utilizar un sistema con varios procesadores es aumentar la potencia de cálculo y, por lo tanto, el rendimiento. El sistema reparte la carga de trabajo entre los procesadores y gestiona la memoria para distribuirla adecuadamente. Los sistemas multiprocesador suelen usarse en estaciones de trabajo, servidores, etc.
#
# <!-- ## Multitarea -->
# En un sistema operativo multitarea, varios procesos pueden ejecutarse aparentemente al mismo tiempo sin que el usuario lo perciba. La mayoría de los sistemas operativos actuales son multitarea.
#
# Un sistema multitarea permite, por ejemplo, escuchar música, navegar por Internet y realizar una videoconferencia simultáneamente. El sistema operativo fracciona el tiempo de CPU y lo distribuye entre los procesos que lo requieren de la mejor forma posible.
#
# ## Multihilo
# Un proceso puede tener varios hilos de ejecución, permitiendo que un proceso ejecute varias tareas al mismo tiempo. El multihilo es eficiente, ya que crear muchos procesos requiere más recursos, mientras que varios hilos pueden compartir los recursos y la memoria de un proceso. Además, el multihilo evita la pérdida de tiempo en cambios de contexto, ya que todos los hilos se ejecutan en el mismo contexto.
#
# ## Multiusuario
# Un sistema operativo multiusuario puede dar servicio a varios usuarios simultáneamente. No hay que confundir un sistema con varias cuentas de usuario con un sistema multiusuario.
#
# Por ejemplo, las versiones domésticas de Windows® permiten tener varias cuentas de usuario, pero no permiten que varios usuarios trabajen al mismo tiempo. En cambio, las versiones Server de Windows® sí lo permiten a través de terminal server. Las versiones de Linux han sido multiusuario desde hace mucho tiempo.

# %% [markdown]
# # Capítulo IV Particionamiento Lógico y Núcleos Virtuales

# %% [markdown]
# ## Historia de la Virtualización
# La virtualización tiene sus inicios en los años 60, cuando IBM desarrolló sistemas de particiones lógicas para sus mainframes, permitiendo que varias máquinas virtuales compartieran un solo sistema físico. Con la llegada de la arquitectura x86 en los 80, el modelo cambió y se redujo la necesidad de virtualización debido al uso de múltiples máquinas físicas.
#
# En los 90, la virtualización resurgió como una solución más económica y eficiente para simplificar sistemas, reducir costos y facilitar la administración. Al principio, los sistemas de virtualización en x86 tenían un rendimiento bajo, pero evolucionaron hasta permitir sistemas operativos virtuales de tipo servidor y la creación de hypervisores. Actualmente, la virtualización es esencial en entornos empresariales, optimizando el uso de hardware, consumo de energía y gestión.
#
# ## Concepto de Virtualización
# La virtualización se implementa en una máquina anfitriona mediante una capa de software que asigna recursos como procesador, memoria y almacenamiento. Esta capa permite instalar y ejecutar sistemas operativos huéspedes que utilizan recursos virtuales, gestionados a través de drivers virtuales, para interactuar con las aplicaciones y el sistema operativo.
#
# La virtualización moderna ha mejorado significativamente gracias al soporte nativo de hardware, lo que la hace más eficiente y sencilla de administrar.

# %% [markdown]
# # Capítulo I Sistemas de Archivo

# %% [markdown]
# El objetivo de un sistema de archivos es el gestionar los ficheros almacenados generalmente
# en un dispositivo físico como un disco duro, unidad SSD, pendrive, etc. El sistema de archivos
# mantiene unas estructuras internas para mantener organizados los ficheros de forma eficiente
# y para que el acceso a los mismos sea rápido.

# %% [markdown]
# # Sistemas de Archivos
#
# ## Sistemas de archivos de disco
# Estos sistemas permiten que múltiples procesos accedan a un fichero sin importar su ubicación en el disco, optimizando el acceso y anticipándose a las demandas de los procesos. Los sistemas más comunes son:
#
# - **FAT16 (FAT)**: Particiones de hasta 2 GB, archivos de máximo 2 GB, unidades de asignación de 32 KB, no distingue mayúsculas/minúsculas. Compatible con la mayoría de los sistemas operativos.
# - **FAT32**: Archivos de hasta 4 GB y particiones de más de 2 GB, con unidades de asignación de 4 KB. Máximo tamaño de partición de 2 TB. No distingue entre mayúsculas/minúsculas.
# - **NTFS**: Volúmenes de hasta 16 EB (implementación actual 256 TB), distingue mayúsculas/minúsculas. Unidades de asignación entre 4 KB y 64 KB.
# - **EXT3**: Propio de Linux, permite particiones de hasta 32 TB y archivos de hasta 2 TB. Distingue mayúsculas/minúsculas.
# - **EXT4**: Utilizado en Linux, soporta particiones de hasta 1 EB y archivos de 16 TB. Distingue mayúsculas/minúsculas.
# - **HFS+**: Sistema de Apple, particiones de hasta 16 EB y archivos de hasta 8 EB.
#
# ## Sistemas de archivos de discos ópticos
# Utilizados en CD, DVD y discos Blu-ray. Los más comunes son:
#
# - **ISO 9660**
# - **UDF (Universal Disk Format)**
#
# ## Sistemas de archivo de cintas
# Debido al almacenamiento secuencial, los accesos aleatorios son más lentos que en discos tradicionales, ya que requieren rebobinar la cinta.
#
# ## Sistemas de archivo de red
# Distribuidos en una red local, donde los clientes acceden a los archivos proporcionados por un servidor. Utilizan protocolos como:
#
# - **NFS (Network File System)**
# - **SMB (Server Message Block)**

# %% [markdown]
# ## Capítulo II Volúmenes lógicos y físicos

# %% [markdown]
# Almacenamiento físico de un sistema
# operativo. Se comenzará estudiando el particionamiento para luego ver conceptos
# como la gestión de volúmenes lógicos o los sistemas RAID

# %% [markdown]
# ### Tipos de Particiones en un Disco Duro
#
# En un disco duro, las particiones permiten dividir el espacio de almacenamiento en secciones independientes para distintos usos. Los tipos de particiones más comunes son:
#
# #### 1. Primaria
# - **Uso principal**: Se utilizan principalmente para instalar sistemas operativos, aunque estos también pueden instalarse en particiones lógicas.
# - **Limitación**: Un disco puede tener hasta **4 particiones primarias** como máximo.
# - **Ejemplo de uso**: Instalación de un sistema operativo o software que requiera acceso directo a una partición primaria.
#
# #### 2. Extendida
# - **Propósito**: Una partición extendida no contiene datos directamente, sino que sirve para albergar **particiones lógicas**.
# - **Características**: Solo puede existir **una partición extendida** por disco, pero puede contener múltiples particiones lógicas dentro de ella.
# - **Ventaja**: Permite superar la limitación de 4 particiones en un disco, facilitando la creación de más particiones para diversos usos.
#
# #### 3. Lógica
# - **Definición**: Son particiones “secundarias” que se encuentran dentro de una partición extendida.
# - **Uso común**: Se utilizan principalmente para almacenar datos, programas o archivos personales.
# - **Flexibilidad**: No hay un límite estricto en el número de particiones lógicas que se pueden crear dentro de una partición extendida, lo que ofrece mayor flexibilidad para gestionar el almacenamiento.
#
# ### Resumen
# Las particiones primarias son ideales para sistemas operativos y tareas críticas, las extendidas permiten la creación de particiones lógicas adicionales, y las lógicas son perfectas para almacenamiento secundario y organización de datos.

# %% [markdown]
# ### El sector de arranque
# Un disco se compone de un sector de arranque y una serie de particiones y opcionalmente
# espacio sin particionar.
# El sector de arranque es el primer sector del disco (cabeza 0, cilindro 0 y sector 1).
# Dentro de él está la tabla de particiones y el Master Boot(MBR) o gestor de arranque.
# Este programa lee la tabla de particiones y cede el control al sector de arranque de la partición
# activa. Como se ha dicho antes si no hay partición activa, el equipo da un error al arrancar.

# %% [markdown]
# ## NAS (Network Attached Storage)
# Un NAS es un dispositivo de almacenamiento conectado a una red que permite a los usuarios almacenar y acceder a datos a través de una red, como si fuera una unidad de disco externa, pero con la ventaja de que se puede acceder de manera remota desde varios dispositivos y sistemas operativos.
#
# Características:
# Almacenamiento de archivos: El NAS está diseñado para almacenar y compartir archivos a través de una red.
# Acceso a través de protocolo de red: Generalmente utiliza protocolos como SMB (Server Message Block) o NFS (Network File System) para compartir archivos entre dispositivos en la red.
# Fácil de configurar: Suele ser más fácil de configurar en comparación con un SAN y es ideal para pequeñas empresas o usuarios domésticos.
# Escalabilidad limitada: Aunque algunos modelos permiten expandir la capacidad de almacenamiento, no está diseñado para gestionar grandes volúmenes de datos o tareas críticas a nivel empresarial.
# Ejemplo:
# Un hogar que tiene múltiples dispositivos como PCs, laptops, tablets y smartphones, podría usar un NAS para almacenar y compartir música, fotos y documentos. Un ejemplo de NAS sería el Synology DiskStation o QNAP TS Series.
#
# SAN (Storage Area Network)
# Una SAN es una red especializada de alto rendimiento que conecta servidores a dispositivos de almacenamiento. A diferencia del NAS, que trabaja a nivel de archivos, el SAN opera a nivel de bloques de datos, lo que permite que las aplicaciones accedan al almacenamiento como si fuera un disco local, brindando mayor velocidad y capacidad para manejar grandes volúmenes de datos.
#
# Características:
# Almacenamiento a nivel de bloques: En lugar de compartir archivos, el SAN permite a los servidores acceder a bloques de datos, lo que hace que el acceso sea más rápido y eficiente.
# Alto rendimiento: Está diseñado para aplicaciones empresariales que requieren acceso rápido a grandes volúmenes de datos.
# Requiere infraestructura más compleja: Configurar un SAN puede ser más complejo y costoso debido a los componentes y el hardware especializados, como switches y cables FC (Fibre Channel).
# Escalabilidad: Las SANs pueden escalarse fácilmente para manejar grandes cantidades de datos y usuarios, lo que las hace ideales para grandes empresas.
# Ejemplo:
# Una empresa grande con múltiples servidores que necesita almacenar grandes bases de datos o archivos de aplicaciones, como un servidor de correo o un servidor de virtualización. Un ejemplo de SAN sería EMC VMAX o NetApp FAS Series.

# %% [markdown]
# # Protección RAID
#
# El sistema **RAID** (Redundant Array of Independent Disks) es una tecnología que utiliza múltiples discos duros para mejorar el rendimiento, la redundancia y la disponibilidad de los datos en un sistema de almacenamiento. La **protección RAID** se refiere a la **redundancia de datos** que proporciona RAID para protegerlos contra fallos de disco.
#
# ## Tipos de RAID comunes con protección de datos:
#
# ### RAID 1 - Espejado (Mirroring)
# - **Protección**: Los datos se duplican en dos discos. Si uno de los discos falla, el sistema puede seguir funcionando con el otro.
# - **Ejemplo**: Si tienes dos discos de 500 GB configurados en RAID 1, los 500 GB de datos se almacenarán en ambos discos. Si uno de los discos falla, no perderás ningún dato.
#
# ### RAID 5 - Paridad distribuida
# - **Protección**: Los datos y la paridad (información de recuperación) se distribuyen entre todos los discos. Si un disco falla, la información perdida se puede reconstruir utilizando la paridad.
# - **Ejemplo**: En un RAID 5 con tres discos de 1 TB, la capacidad usable sería 2 TB, ya que el 1 TB restante se utiliza para la paridad. Si uno de los discos falla, se puede recuperar toda la información utilizando los datos y la paridad distribuidos en los otros discos.
#
# ### RAID 10 (1+0) - Combinación de RAID 1 y RAID 0
# - **Protección**: Combina la redundancia del RAID 1 con la velocidad del RAID 0. Los datos se espejan (como en RAID 1) y luego se distribuyen entre los discos (como en RAID 0).
# - **Ejemplo**: Si tienes 4 discos de 500 GB configurados en RAID 10, tendrás 1 TB de capacidad utilizable. Ofrece mayor redundancia y rendimiento, ya que puedes perder hasta 2 discos (si son del mismo par espejado) sin perder datos.
#
# ## Ventajas de la protección RAID:
# - **Alta disponibilidad**: RAID garantiza que los datos estén protegidos y accesibles incluso si un disco falla.
# - **Recuperación de fallos**: La paridad o duplicación de datos permite la recuperación de los mismos en caso de fallo de un disco.
# - **Mejora del rendimiento**: Algunos niveles de RAID también mejoran la velocidad de lectura y escritura de los datos.
#
# ## Desventajas:
# - **Requiere más discos**: Los sistemas RAID con protección de datos (como RAID 1 y RAID 5) necesitan más discos que un sistema sin RAID.
# - **Riesgo de fallo de múltiples discos**: Aunque RAID ofrece protección contra fallos de un disco, puede no ser suficiente si fallan más de uno al mismo tiempo.
#
# En resumen, RAID es una solución de almacenamiento que mejora la **seguridad** y la **disponibilidad** de los datos al repartir la carga entre varios discos y protegerlos contra fallos.

# %% [markdown]
# # Capítulo III Políticas de Salvaguarda

# %% [markdown]
# # Ejemplo de Plan de Continuidad de Negocio
#
# ## Estrategias Principales
# El plan se basa en tres estrategias clave:
# - **Prevención**: Implementar medidas proactivas para evitar incidentes.
# - **Mitigación**: Minimizar el impacto de los incidentes cuando ocurran.
# - **Recuperación**: Restablecer operaciones en el menor tiempo posible.
#
# ## Medidas de Continuidad
# Para asegurar la continuidad del negocio, se deben incluir:
# 1. **Copias de Seguridad**:
#    - Almacenar datos en **centros de datos separados** geográficamente.
# 2. **Conexiones de Alta Velocidad**:
#    - Utilizar enlaces rápidos entre los centros para replicar datos en tiempo real.
# 3. **Infraestructura Paralela**:
#    - Implementar sistemas redundantes que asuman la carga en caso de fallos.
#
# ## Seguridad Física
# Es fundamental contar con medidas de protección física:
# - **Control de acceso**: Restricción de entrada a zonas críticas.
# - **Protección del cableado**: Resguardar la infraestructura de comunicaciones.
# - **Precauciones antiincendio**: Detectores de humo y sistemas de extinción.
# - **Control de inundaciones**: Sensores y barreras para evitar daños por agua.

# %% [markdown]
# # Capítulo III: Políticas de Salvaguarda
#
# La supervivencia de una empresa depende de factores internos y externos, incluyendo económicos, demográficos y de mercado. Es responsabilidad de la empresa implementar medidas que aseguren la continuidad de sus operaciones ante situaciones adversas.
#
# Las grandes empresas suelen contar con un **plan de continuidad de negocio**, que establece los recursos, capacidades y procedimientos necesarios para mitigar los efectos de riesgos o eventos externos. Este plan se basa en tres estrategias principales:
#
# - **Estrategias de prevención**
# - **Estrategias de mitigación**
# - **Estrategias de recuperación**
#
# Para garantizar la continuidad, es fundamental reducir el tiempo de recuperación y el punto de recuperación. Esto se logra mediante:
#
# - **Copia de datos en centros distintos**
# - **Conexiones de alta velocidad entre centros**
# - **Infraestructura paralela para absorber actividad en caso de incidentes**
#
# El plan de continuidad también contempla la seguridad física, que incluye:
#
# - **Control de acceso a la sala**
# - **Protección del cableado estructurado**
# - **Precauciones antiincendio**
# - **Sistemas de control ante inundaciones**
#
# ## Salvaguarda Lógica
# La **salvaguarda lógica** consiste en la aplicación de barreras y procedimientos que resguarden el acceso a los datos y solo se permita acceder a ellos a las personas autorizadas para hacerlo.
#
# ### Objetivos Principales:
# - **Restringir el acceso** a los programas y archivos a usuarios sin los permisos correspondientes.
# - **Asegurar que los usuarios puedan trabajar sin supervisión exhaustiva** y no puedan modificar los programas ni los archivos que no les correspondan.
# - **Asegurar el uso correcto** de los datos, archivos y programas por el procedimiento adecuado.
# - **Controlar la transmisión de información** para que solo el destinatario previsto la reciba.
# - **Comprobar la integridad** de la información transmitida y recibida.
# - **Implementar sistemas alternativos** de transmisión entre diferentes puntos.
# - **Disponer de soluciones de emergencia** para la transmisión de información.
#
# Estos controles pueden implementarse en:
# - **Sistemas operativos**
# - **Sistemas de aplicación**
# - **Bases de datos**
# - **Paquetes específicos de seguridad**
#
# Estos mecanismos ayudan a proteger el sistema operativo de la red, el sistema de aplicación y el software de la utilización o modificaciones no autorizadas, garantizando la integridad de la información y restringiendo el acceso a usuarios y procesos autorizados. Además, se debe complementar con **backups o clonaciones** para evitar la pérdida de datos por errores o fallos de hardware o software.

# %% [markdown]
# # Clonaciones
#
# Una **clonación** es una copia exacta de algo. En informática, puede ser de un disco o una partición.
#
# ## Diferencias entre clonar un disco y una partición
#
# ### Clonación de un disco
# - Incluye el **sector de arranque**.
# - Permite que el equipo arranque y funcione al recuperar la imagen en otro disco.
# - Posibilita duplicar equipos informáticos, siempre que el hardware sea igual.
#
# ### Clonación de una partición
# - Solo guarda los datos de una **partición específica**, sin incluir el sector de arranque.
# - No permite duplicar equipos.
#
# ## Consideraciones
# - Si el disco no tiene sistema operativo para arrancar, es suficiente clonar las particiones y recuperarlas en otro disco para conservar los mismos datos.

# %% [markdown]
# # Alta Disponibilidad
#
# La **alta disponibilidad** no implica necesariamente hardware y software de alto coste. Existen soluciones accesibles para muchas empresas, asegurando la disponibilidad de los sistemas de información **24/7** y evitando pérdidas de negocios o información por fallos.
#
# ## Conceptos clave
#
# ### Fiabilidad
# - Es la **probabilidad de que un sistema funcione normalmente** durante un período determinado.
# - Se asocia a la **continuidad del servicio**.
# - Define si un sistema puede ser utilizado en condiciones óptimas.
#
# ### Disponibilidad
# - Hace referencia a que los sistemas estén operativos y accesibles en todo momento.
#
# ## Estados del servicio
# - **Apropiado**: Satisface las expectativas del usuario.
# - **No apropiado**: No cumple las expectativas debido a errores o fallos.
#
# ## Problemas y errores
# - Un fallo ocurre cuando un servicio no funciona correctamente o no cumple con las especificaciones.
# - No todos los errores provocan una interrupción inmediata, pero afectan el funcionamiento adecuado del sistema.

# %% [markdown]
# # Clustering y Balanceo de Carga
#
# El **balanceo de carga** o **clustering** consiste en una disposición de varios equipos que comparten esfuerzos para realizar una tarea determinada. Si uno de los equipos falla, otro miembro del cluster toma el relevo.
#
# ## Características principales
#
# ### Balanceo de carga
# - Comúnmente utilizado en **servidores web** para manejar altos volúmenes de peticiones.
# - Distribuye las tareas entre los equipos del cluster para optimizar el rendimiento.
#
# ### Escalabilidad
# - Los clusters permiten **ampliar su capacidad** añadiendo más equipos al grupo.
#
# ### Tolerancia a fallos
# - Si un equipo del cluster falla:
#   - Los demás miembros asumen las tareas del equipo caído.
#   - El servicio continúa sin interrupciones.
#   - Puede haber una ligera disminución en la eficiencia, pero nunca una paralización total.

# %% [markdown]
# # Diferencias entre Clustering y Grid Computing
#
# Aunque ambos conceptos utilizan varios equipos para realizar tareas o servicios, **clustering computing** y **grid computing** tienen diferencias significativas en su enfoque y funcionamiento.
#
# ## Clustering Computing
# - **Definición**: Una misma aplicación corre en múltiples servidores con **redundancia**.
# - **Dependencia**: Los servidores del cluster tienen **gran dependencia** entre sí.
# - **Funcionamiento**: Todos los miembros del cluster realizan el **mismo trabajo**.
# - **Objetivo**: Garantizar la continuidad de un servicio o aplicación incluso ante fallos de hardware o software.
# - **Uso común**: Servicios que requieren alta disponibilidad y tolerancia a fallos.
#
# ## Grid Computing
# - **Definición**: Divide una aplicación en módulos que operan en servidores distintos **sin redundancia**.
# - **Independencia**: Los servidores del grid son **independientes** entre sí.
# - **Funcionamiento**: Cada servidor realiza tareas **diferentes y específicas**, trabajando en paralelo.
# - **Objetivo**: Resolver problemas complejos que demandan gran potencia de cálculo, distribuyendo el trabajo.
# - **Uso común**: Proyectos de investigación o problemas computacionales complejos que requieren **procesamiento distribuido**.
#
# ## Ejemplo Comparativo
# - **Clustering**: Asegura que un servicio web siga funcionando aunque un servidor falle.
# - **Grid Computing**: Divide cálculos complejos en módulos, procesados por varios servidores y combinados al final, como en proyectos científicos.
#
# ## Analogía
# - **Clustering**: Varios equipos trabajan juntos como una unidad redundante.
# - **Grid Computing**: Una supercomputadora distribuida, donde cada equipo aporta capacidad de cálculo específica.

# %% [markdown]
# # Integridad de Datos y Recuperación de Servicio
#
# ## Integridad de Datos
#
# Los datos son uno de los activos más valiosos para cualquier empresa, y garantizar su **exactitud** y **fiabilidad** es esencial. Sin embargo, la integridad de los datos puede verse comprometida por diversos factores, como:
#
# - **Errores humanos**: Cambios intencionados o accidentales realizados por miembros de la organización.
# - **Fallos en sistemas**: Problemas en la transferencia o almacenamiento de datos.
#
# ### Prevención y Protección
#
# Al diseñar un sistema, es crucial:
# 1. **Identificar amenazas potenciales**.
# 2. Implementar **mecanismos de protección** para preservar los datos:
#    - Uso de bases de datos seguras como punto central de protección.
#    - Incorporación de herramientas como **antivirus** y **cortafuegos**.
# 3. Incorporar **mecanismos de detección** para identificar problemas, incluyendo aquellos causados por **malware**.
#
# Garantizar la integridad de los datos no solo implica prevenir daños, sino también detectar posibles vulnerabilidades que puedan afectar su fiabilidad.

# %% [markdown]
# # Plan de Recuperación de Servicios
#
# Un **plan de recuperación del servicio** es parte integral del plan de contingencias de una empresa, diseñado para restaurar los servicios tras una amenaza. Su objetivo es devolver el servicio a su estado previo al desastre o a un estado funcionalmente aceptable.
#
# ## Pasos para Crear un Plan de Recuperación
#
# 1. **Análisis de riesgos e impactos**:
#    - Identificar posibles amenazas.
#    - Evaluar daños potenciales.
#
# 2. **Definir acciones y medidas**:
#    - Establecer políticas de **backup**.
#    - Prever la existencia de un **centro de respaldo**.
#
# 3. **Parámetros clave**:
#    - **RTO (Recovery Time Objective)**: Tiempo máximo permitido para restaurar el servicio.
#    - **RPO (Recovery Point Objective)**: Punto en el tiempo desde el que se deben recuperar los datos.
#
# Este plan asegura la continuidad operativa, minimizando el impacto de interrupciones y acelerando la recuperación.

# %% [markdown]
# # RTO (Recovery Time Objective)
#
# El **RTO (Recovery Time Objective)** es el tiempo máximo que un sistema puede estar inactivo tras un desastre antes de ser restablecido. Este tiempo se cuenta desde la notificación de la caída del servicio y tiene un límite, ya que superarlo puede tener consecuencias graves para la continuidad del negocio.
#
# El objetivo de los responsables de sistemas es reducir el RTO al menor tiempo posible para minimizar el impacto de las interrupciones.
#
# ---
#
# # RPO (Recovery Point Objective)
#
# El **RPO (Recovery Point Objective)** es el período máximo que puede pasar un sistema caído sin que se pierdan datos importantes, según lo estipulado en el plan de continuidad de negocio. Si este tiempo se excede, las consecuencias negativas para la empresa suelen ser significativas.
#
# En caso de una caída, será necesario recuperar los datos perdidos durante el tiempo en que el sistema estuvo fuera de servicio. Si se acepta cierta pérdida de datos, el RPO será mayor, pero si no se acepta ninguna pérdida, el RPO será **cero**. A menor RPO, mayor será la frecuencia de las copias de seguridad necesarias.

# %% [markdown]
# # Custodia de Ficheros de Seguridad
#
# La **custodia de los datos** es una tarea esencial en cualquier empresa, ya que los datos son uno de los activos más valiosos. Sin embargo, muchas empresas se enfocan en asegurar el acceso al sistema y a los datos, pero descuidan la seguridad en la **custodia de backups** y otros datos importantes, lo cual es un grave error.
#
# ## Principios de la Custodia de Datos
#
# 1. **Nivel de seguridad alto**:
#    - La custodia de los datos debe tener al menos el mismo nivel de seguridad que el acceso a ellos.
#
# 2. **Preservación de medios físicos**:
#    - Cintas de backup, discos duros y otros medios deben conservarse adecuadamente, protegiéndolos de deterioros como incendios, inundaciones, etc.
#    - Los medios de almacenamiento deben almacenarse en ubicaciones separadas de los datos originales para reducir riesgos.
#
# 3. **Destrucción segura de material confidencial**:
#    - Es fundamental destruir adecuadamente los datos confidenciales mediante normas como la UNE-EN 15713:2010 para garantizar la seguridad.
#
# ## Backup Remoto
#
# Las empresas que no están preparadas para la custodia de datos pueden recurrir a servicios de **backup remoto** (offsite backup o vaulting). Esto es importante, ya que los desastres locales como incendios o inundaciones pueden destruir tanto los datos como los backups si no se encuentran en un lugar separado.
#
# ### Opciones de Backup Remoto
#
# 1. **Copia local y custodia en un lugar distinto**.
# 2. **Uso de un servicio de backup remoto**: Los datos se envían electrónicamente a una ubicación segura fuera de las instalaciones de la empresa.
#
# ### Beneficios del Backup Remoto
#
# - **Reducción de riesgos**: Menor exposición a desastres naturales, incendios, y otros eventos locales.
# - **Costos reducidos**:
#   - Ahorro de tiempo y recursos del personal en realizar y verificar los backups.
#   - Reducción de costos en soportes, hardware y espacio de almacenamiento.
#   - Menor exposición a virus o ataques de hackers.
#
# ### Servicios Especializados en Backup Remoto
#
# Las compañías especializadas en backup remoto ofrecen diversos servicios, como:
# - Planificación de backups.
# - Versionado de backups (almacenamiento de los últimos backups).
# - Realización de backups incrementales automáticos.
# - Encriptación de datos.
# - Backup especializado para bases de datos.
#
# Algunas empresas optan por almacenar datos en lugares como **minas no utilizadas** o **infraestructuras militares**, donde la seguridad es más alta y los riesgos de desastres son menores.
#
# En resumen, la custodia adecuada de datos y el uso de servicios de backup remoto son fundamentales para proteger la información valiosa de una empresa frente a posibles amenazas.

# %% [markdown]
# # Capítulo IV: Políticas de Seguridad
#
# En este capítulo se abordan varios aspectos fundamentales de las **políticas de seguridad**, como el acceso restringido por cuentas de usuario, el uso de antivirus, auditorías de seguridad, y la implementación de cortafuegos y servidores proxy.
#
# ## Acceso Restringido por Cuentas de Usuario
#
# En sistemas informáticos, especialmente en **Linux/Unix**, el acceso se realiza a través de **cuentas de usuario**. Estas cuentas permiten a los usuarios acceder a los recursos del sistema (como ficheros y procesos) bajo las condiciones de privilegios específicos.
#
# ### Principales Componentes de la Gestión de Cuentas
#
# - **Cuentas de usuario**: Permiten que los usuarios accedan a los recursos, y generalmente pertenecen a uno o más **grupos**. Los grupos permiten especificar permisos de acceso comunes a un conjunto de usuarios.
# - **Identificadores**: Cada cuenta de usuario y grupo tiene un **ID único (UID)** y un **GID** (ID de grupo), que son los que el sistema utiliza para asignar permisos de acceso. Estos identificadores se encuentran en el archivo `/etc/passwd` en sistemas **Linux/Unix**.
# - **Propietarios de recursos**: Los ficheros y procesos tienen un **propietario**. El usuario propietario puede cambiar los permisos del fichero (lectura, escritura, ejecución) y realizar otras acciones como transferir la propiedad a otro usuario.
# - **Superusuarios**: Los superusuarios (como **root** en Unix o **Administrador** en Windows) tienen privilegios completos y pueden eludir todas las restricciones de acceso.
#
# ### Información Asociada a las Cuentas de Usuario
#
# Cada cuenta de usuario tiene información asociada, que puede incluir:
# - Nombre de usuario.
# - Contraseña.
# - UID (ID de usuario).
# - GID (ID de grupo).
# - Directorio personal.
# - Información adicional (como email, configuraciones específicas, nombre real, flags sobre habilitación o accesibilidad remota).
#
# ### Tipos de Cuentas de Usuario
#
# 1. **Usuarios normales**: Acceden solo a los recursos a los que tienen permiso. Los administradores crean **grupos** para establecer permisos de acceso.
# 2. **Superusuarios o administradores**: Tienen derechos completos sobre el sistema y pueden modificar su configuración.
# 3. **Cuentas de invitados**: Se utilizan para accesos temporales, y suelen estar protegidas con contraseña para evitar accesos no autorizados. Tienen permisos limitados.
# 4. **Usuarios específicos**: Se utilizan para tareas de mantenimiento o administración como la realización de copias de seguridad.

# %% [markdown]
# # Propiedad de la Información
#
# La **información** de una entidad es un activo que le pertenece, y es responsabilidad de la entidad **preservarla** mediante políticas de seguridad, velando por el cumplimiento de las mismas.
#
# ### Disponibilidad y Acceso
#
# - La información debe estar **disponible** solo para las personas que la necesiten para el desarrollo o cumplimiento de sus funciones.
# - Cada persona es **responsable** de la información a la que se le ha otorgado acceso, y debe utilizarla únicamente para los fines establecidos.
#
# ### Centralización de la Información
#
# Para un mejor control, es recomendable tener un **sistema centralizado** de información:
# - La centralización permite tener un **mayor control** sobre la seguridad de los datos, concentrando los esfuerzos de seguridad en un solo punto.
# - En un **sistema descentralizado**, los esfuerzos de seguridad deben dividirse entre varios puntos, lo que aumenta el nivel de **riesgo**.

# %% [markdown]
# ## Identificador de Único Acceso
#
# Todo usuario que se conecte a un sistema debe ser validado e identificado de forma unívoca. Esto implica que cada usuario esté asociado a una persona real, permitiendo que cualquier operación realizada pueda ser imputada a esa persona. Las reglas a seguir en el control de acceso son:
#
# - **Una persona <-> un usuario:** Evitar cuentas grupales que no identifiquen a la persona que accede al sistema.
# - **Identificador único (UID):** Cada usuario tiene un UID que permite al sistema reconocerlo.
# - **No reutilizar identificadores:** Los identificadores no deben ser reutilizados ni duplicados.
# - **Identificadores únicos:** No pueden existir identificadores iguales.
# - **No modificar identificadores:** Los identificadores no deben cambiarse una vez asignados.
# - **Usuarios externos identificados:** Los usuarios invitados deben estar correctamente identificados.
# - **Nomenclatura clara:** Adoptar una nomenclatura que identifique a usuarios internos, externos, administradores, etc.
# - **Imputación de operaciones:** Cualquier operación sobre los recursos del sistema debe ser atribuida al identificador único.
# - **Responsabilidad de los administradores:** Los administradores son responsables de la gestión de los usuarios.

# %% [markdown]
# ## Identificación en el Sistema Mediante Certificado
#
# Los certificados de usuario permiten identificar a los usuarios en un sistema, ya que contienen datos sobre su identidad. Esto facilita la creación de mecanismos de control y autenticación avanzados. Los puntos clave sobre la identificación mediante certificados son:
#
# - **Protección con contraseña:** Los certificados deben estar protegidos con una contraseña para garantizar su seguridad.
# - **Instalación en el sistema:** Los certificados deben instalarse en el sistema del usuario para poder acceder a los datos en el servidor.
# - **Almacenamiento en tarjeta inteligente:** Los certificados también pueden almacenarse en tarjetas inteligentes, haciendo el proceso de autenticación más versátil.
# - **Servicios de certificación:** Sistemas operativos como Linux y Windows® Server incluyen servicios de certificación, permitiendo que las organizaciones emitan sus propios certificados.

# %% [markdown]
# ## Protección Antivirus
#
# Cuando un equipo experimenta bloqueos, reinicios, lentitud o no arranca, puede estar infectado por un virus o malware, aunque no siempre es fácil detectar si un sistema está infectado, lo que aumenta su peligrosidad. En muchos casos, el usuario solo se da cuenta cuando ya es demasiado tarde.
#
# Un antivirus es un software cuyo objetivo es:
#
# - **Detectar los virus**
# - **Prevenir las infecciones por virus**
# - **Analizar el sistema en busca de virus**
# - **Eliminar los virus detectados**
#
# ### Técnicas de Antivirus
#
# Existen dos técnicas principales utilizadas por los antivirus:
#
# 1. **Técnica de Scanning:**
#    - Los antivirus contienen una base de datos con los códigos de virus conocidos.
#    - Cuando se escanea un archivo, se compara su código con los virus en la base de datos (llamados firmas o vacunas).
#    - Si hay coincidencias, el antivirus identifica el virus y lo elimina o lo pone en cuarentena.
#    - Esta técnica está en desuso ya que solo actúa después de la infección.
#
# 2. **Técnicas Heurísticas:**
#    - Además de hacer comprobaciones de firmas, los antivirus monitorizan programas en busca de comportamientos sospechosos propios de virus.
#    - El desafío es que algunos programas legítimos pueden ser erroneamente clasificados como virus debido a su comportamiento.
#
# La mayoría de los antivirus modernos combinan estas técnicas para proteger el sistema, analizando no solo virus, sino también otros tipos de malware como **spam**, **adware**, **spyware**, etc.

# %% [markdown]
# ## Auditorías de Seguridad
#
# Las auditorías de seguridad en sistemas informáticos se realizan de forma rigurosa, independiente y sistemática, con el objetivo de obtener evidencia de que el sistema cumple con los requisitos de seguridad para los que fue diseñado. Al final, se genera un informe donde se evalúan de manera objetiva los resultados de la revisión del sistema.
#
# ### Tipos de Auditorías
#
# 1. **Auditorías Externas:**
#    - El auditor no tiene ninguna responsabilidad en la actividad que está auditando, lo que garantiza su independencia.
#    - Pueden ser realizadas por clientes o por empresas externas contratadas específicamente para este propósito.
#
# 2. **Auditorías Internas:**
#    - Son realizadas por personal dentro de la misma empresa.
#    - La independencia del equipo auditor puede estar en duda, ya que podrían estar implicados en el sistema auditado.
#    - Sin embargo, se les otorga la mayor independencia posible para asegurar resultados objetivos.
#
# Las auditorías son llevadas a cabo por especialistas en el tema de seguridad informática.

# %% [markdown]
# ## Auditores Informáticos
#
# Los auditores informáticos son profesionales especializados en la auditoría de sistemas informáticos, con un enfoque particular en la seguridad. Generalmente, tienen un amplio conocimiento en el campo de la informática y se caracterizan por ser metódicos, observadores y tener un buen sentido común.
#
# ### Características de un Auditor Informático
#
# - **Independencia:**
#   La imparcialidad y objetividad son esenciales en el trabajo del auditor. Las conclusiones del informe deben basarse únicamente en la evidencia, evitando cualquier sesgo. Si se utiliza muestreo, debe estar claramente reflejado.
#
# - **Conducta Ética:**
#   La discreción, confianza e integridad son fundamentales en el perfil de un auditor.
#
# - **Competencia, Tacto y Talante:**
#   Dado que el trabajo de un auditor es de gran importancia, debe realizarse con meticulosidad, manteniendo la confianza tanto del cliente auditado como de otras partes involucradas.

# %% [markdown]
# ## Objetivos de las Auditorías de un Sistema Informático
#
# Las auditorías de un sistema informático se enfocan principalmente en evaluar la seguridad del sistema y verificar si cumple con los requisitos establecidos. Su propósito es identificar deficiencias y posibles mejoras que deban implementarse para asegurar que el sistema cumpla los objetivos propuestos.
#
# En caso de encontrar alguna deficiencia o área de mejora, el auditor debe registrarlo de manera detallada en el informe de auditoría.

# %% [markdown]
# ## Ventajas de las Auditorías
#
# La realización periódica de auditorías informáticas es fundamental para mejorar la eficacia y eficiencia de un sistema. Ya sea de forma interna o externa, las auditorías ayudan a identificar y corregir deficiencias. Entre los puntos clave que suelen revisarse en las auditorías de seguridad, se incluyen:
#
# - **Seguridad física**: Protege las instalaciones para evitar accesos no autorizados. Esto previene el robo de discos de respaldo, computadoras o cualquier otro equipo valioso.
#
# - **Control de accesos al sistema**: Se verifica que el sistema de usuarios y contraseñas sea efectivo. La seguridad de las contraseñas pierde valor si estas no se gestionan correctamente (por ejemplo, apuntándolas en un cuaderno cerca del equipo).
#
# - **Proteger la lógica del sistema**: La protección a nivel lógico abarca varias capas:
#   - **Nivel de aplicaciones**: Controlando accesos no autorizados y asegurando que las aplicaciones gestionen correctamente los datos.
#   - **Nivel de sistema operativo**: Protegiendo el sistema operativo contra malware y asegurando que esté actualizado con las últimas actualizaciones de seguridad.
#   - **Nivel de base de datos**: Garantizando que el acceso a la base de datos esté restringido solo a las aplicaciones autorizadas.
#   - **Nivel de red**: Asegurando la seguridad de la red para evitar intrusos.

# %% [markdown]
# ## Cortafuegos y Servidores Proxy
#
# ### Cortafuegos (Firewall)
#
# Un cortafuegos es un sistema que filtra la transferencia de información en función de reglas de seguridad determinadas. Su función es examinar toda la información entrante y saliente, bloqueando aquella que no cumpla con los criterios establecidos. Las reglas más comunes incluyen el bloqueo de puertos específicos para impedir la comunicación por ellos. Además de reglas simples, también pueden crearse reglas más complejas.
#
# Existen dos tipos de firewalls dependiendo de su ámbito de aplicación:
# - **Firewall de equipo**: Filtra el contenido entre el equipo y la red a la que está conectado.
# - **Firewall de red**: Generalmente asociado a un router, filtra el contenido entre dos redes, como la red de área local (LAN) e Internet.
#
# ### Servidores Proxy
#
# Los servidores proxy son software, dispositivos o equipos que actúan como intermediarios entre la comunicación de dos máquinas. Su finalidad incluye:
# - Garantizar el anonimato.
# - Mejorar la seguridad o el rendimiento.
# - Optimizar el tráfico.
# - Filtrar o modificar contenidos.

# %% [markdown]
# ![image.png](attachment:image.png)
